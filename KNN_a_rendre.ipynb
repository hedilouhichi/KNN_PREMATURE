# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# DATA IMPORTING

# %%
data = pd.read_csv('Prematures.csv')
data.head()
# Out:
#    GEST  DILATE  EFFACE  CONSIS  CONTR  MEMBRAN   AGE  STRAT  GRAVID  PARIT  \
# 0  31.0     3.0   100.0     3.0    1.0      2.0  26.0    3.0     1.0    0.0
# 1  28.0     8.0     0.0     3.0    1.0      2.0  25.0    3.0     1.0    0.0
# 2  31.0     3.0   100.0     3.0    2.0      2.0  28.0    3.0     2.0    0.0
# 3  27.0     2.0    75.0     3.0    2.0      2.0  27.0    2.0     2.0    1.0
# 4  28.0     6.0    75.0     3.0    2.0      2.0  17.0    3.0     1.0    0.0
#
#    DIAB  TRANSF  GEMEL PREMATURE
# 0   2.0     2.0    1.0   positif
# 1   2.0     1.0    2.0   positif
# 2   2.0     1.0    1.0   positif
# 3   2.0     1.0    2.0   positif
# 4   2.0     1.0    1.0   positif

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GEST       390 non-null    float64
#  1   DILATE     390 non-null    float64
#  2   EFFACE     390 non-null    float64
#  3   CONSIS     390 non-null    float64
#  4   CONTR      390 non-null    float64
#  5   MEMBRAN    390 non-null    float64
#  6   AGE        390 non-null    float64
#  7   STRAT      390 non-null    float64
#  8   GRAVID     390 non-null    float64
#  9   PARIT      390 non-null    float64
#  10  DIAB       390 non-null    float64
#  11  TRANSF     390 non-null    float64
#  12  GEMEL      390 non-null    float64
#  13  PREMATURE  390 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 42.8+ KB

# %%
data.describe()
# Out:
#              GEST      DILATE      EFFACE      CONSIS       CONTR     MEMBRAN  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    30.302564    1.241026   43.979487    2.392308    1.094872    1.802564
# std      3.145281    1.307821   34.829435    0.722351    0.310443    0.480460
# min     20.000000    0.000000    0.000000    1.000000    1.000000    1.000000
# 25%     28.000000    0.000000    0.000000    2.000000    1.000000    2.000000
# 50%     31.000000    1.000000   50.000000    3.000000    1.000000    2.000000
# 75%     33.000000    2.000000   75.000000    3.000000    1.000000    2.000000
# max     35.000000    8.000000  100.000000    3.000000    3.000000    3.000000
#
#               AGE       STRAT      GRAVID       PARIT        DIAB      TRANSF  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    26.341026    3.225641    2.302564    0.779487    2.025641    1.517949
# ...

# %%
data.nunique()
# Out:
# GEST         16
# DILATE        8
# EFFACE       17
# CONSIS        3
# CONTR         3
# MEMBRAN       3
# AGE          26
# STRAT         4
# GRAVID       10
# PARIT         8
# DIAB          3
# TRANSF        2
# GEMEL         2
# PREMATURE     2
# dtype: int64

# %% [markdown]
# I)DATA CLEANING

# %%
dataD=data.dropna()

# %% [markdown]
# 1)ENCODAGE

# %%
dataD['PREMATURE'] = pd.get_dummies(dataD.PREMATURE).iloc[:,1:]

# %%
import seaborn as sns 

# Correlating features with target
plt.figure(figsize=(2, 7))
heatmap = sns.heatmap(dataD.corr()[['PREMATURE']]
                      .sort_values(by='PREMATURE', ascending=False),
                      vmin=0, vmax=1, annot=True, cmap='Blues')

# %%
dataD['PREMATURE'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# outliers checking

# %%
l=['GEST', 'DILATE', 'EFFACE', 'CONSIS',  'AGE','STRAT', 'GRAVID', 'PARIT', 'TRANSF', 'MEMBRAN',]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def boxplots(col):
  sns.boxplot(data[col])
  plt.show()
for i in  l:
  boxplots(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
def distplots(col):
  sns.distplot(dataD[col])
  plt.show()
for i in l:
  distplots(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
print(data.boxplot(grid=True, rot=90, fontsize=13))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# REMOVING outliers

# %%
#col=dataD.columns.tolist()
col=['AGE','DILATE','STRAT','GRAVID','GEST']

# %%
import sklearn
from sklearn.datasets import load_boston

upper=set()
lower=set()
up_low=set()
#''' Detection '''
# IQR
for i in col :
  Q1 = np.percentile(dataD[i], 25,interpolation = 'midpoint')
  Q3 = np.percentile(dataD[i], 75,interpolation = 'midpoint')
  IQR = Q3 - Q1
  # Upper bound
  upper.update(e for l in np.where(dataD[i] >= (Q3+1.5*IQR)) for e in l )
  # Lower bound
  lower.update(e for l in np.where(dataD[i] <= (Q1-1.5*IQR)) for e in l )
print(upper)
print(lower)
print("Old Shape: ", dataD.shape) 
''' Removing the Outliers '''
up_low.update(upper)
up_low.update(lower)
#if u wanna remove the outliers uncomment the code below 

#dataD.drop(up_low, inplace = True)

 
print("New Shape: ", dataD.shape)
# Out:
# {1, 4, 137, 138, 268, 274, 148, 277, 22, 151, 149, 285, 173, 47, 318, 319, 91, 347, 93, 97, 359, 365, 242, 375}
# {100, 358, 329, 266, 60, 272, 114, 148, 118, 247, 248, 347, 28, 318}
# Old Shape:  (390, 14)
# New Shape:  (390, 14)

# %%
print(dataD.boxplot(grid=True, rot=90, fontsize=13))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# unscrew target value and independing values

# %%
X =dataD.drop(['PREMATURE'], axis=1)
Y=dataD['PREMATURE']

# %% [markdown]
# Balenced the dataset

# %% [markdown]
# Oversampling is a technique to alter unequal classes of data to create balanced datasets. This technique attempts to increment the size of rare samples to create a balance when the data is insufficient.
#
# For example, let’s have a classification problem with two classes and 100K data points. 20K data points are of the positive class, 80K for the negative class. The positive class, which is the minority class, would need to be oversampled

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
print(Counter(Y))
# Out:
# Counter({1: 266, 0: 124})

# %%
ros=RandomOverSampler()
X_ros ,Y_ros=ros.fit_resample(X,Y)
print(Counter(Y_ros))
# Out:
# Counter({1: 266, 0: 266})

# %% [markdown]
# Diviser les données en données d'apprentissage et données de test.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_ros, Y_ros, test_size = 0.2, random_state = 0)

# %% [markdown]
# Centrage-Réduction des données (Standardisation)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (425, 13)

# %%
X_test.shape
# Out:
# (107, 13)

# %% [markdown]
# **Phase d'apprentissage: Appliquer le modèle KNN avec les données d'apprentissage**

# %%
from sklearn.neighbors import KNeighborsClassifier

error = []
for i in range(1, 20):
    knn = KNeighborsClassifier(i,metric='euclidean')
    knn_model = knn.fit(X_train, Y_train)
    pred_i = knn_model.predict(X_test)
    error.append(np.mean(pred_i != Y_test))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 20), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Taux Erreur pour les differentes valeurs de k')
plt.xlabel('K ')
plt.ylabel('Erreur')
# Out:
# Text(0, 0.5, 'Erreur')

# %%
from sklearn.model_selection import GridSearchCV
leaf_size = list(range(1,20))# Par défaut c'est 30
n_neighbors = list(range(1,25))
p=[1,2] #p = 1 manhattan_distance/p=2 euclidean_distance
#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
#Create new KNN object
knn_2 = KNeighborsClassifier()
#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10, n_jobs=-1)
#n_jobs: number of CPU'sfor execution.
#cv: number of folds of the cross validation

#Fit the model
best_model = clf.fit(X_train, Y_train)
#Print The value of best Hyperparameters
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
# Out:
# Best leaf_size: 1
# Best p: 1
# Best n_neighbors: 1

# %%
best_parameters = clf.best_params_
print(best_parameters)
# Out:
# {'leaf_size': 1, 'n_neighbors': 1, 'p': 1}

# %%
#Taux de bonne classification
best_result = clf.best_score_
print(best_result)
# Out:
# 0.7931893687707641

# %%
knn = KNeighborsClassifier(1,p=2,leaf_size=1 )
knn_model = knn.fit(X_train, Y_train)
y_pred_knn = knn_model.predict(X_test)

# %%
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, Y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, Y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 1.00
# Accuracy of K-NN classifier on test set: 0.84

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test, y_pred_knn))
# Out:
# [[44  5]
#  [12 46]]

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        49
#            1       0.90      0.79      0.84        58
#
#     accuracy                           0.84       107
#    macro avg       0.84      0.85      0.84       107
# weighted avg       0.85      0.84      0.84       107

# %%
plt.figure(figsize=(12,5))
p = sns.lineplot(range(1,108),Y_test,marker='*',label='Train Score')
p = sns.lineplot(range(1,108),y_pred_knn,marker='o',label='Test Score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(12,5))
p = sns.lineplot(range(1,108),Y_test,marker='o',label='Test Score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
